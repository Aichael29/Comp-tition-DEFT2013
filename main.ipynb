# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
df = pd.read_csv('C:/Users/dell latitude 7400/Downloads/train.csv')


print("Column names in the DataFrame:", df.columns)

train_df, valid_df = train_test_split(df, test_size=0.2, random_state=42)

# 80%

train_df.to_csv('training_subset.csv', index=False)


vectorizer = CountVectorizer()
y_train = train_df['type']  # 'type' column for the target
baseline_model = DummyClassifier(strategy='most_frequent', random_state=42)
baseline_model.fit(X_train, y_train)


X_valid = vectorizer.transform(valid_df['titre'])  
y_valid = valid_df['type']  

# baseline model
baseline_predictions = baseline_model.predict(X_valid)


print("Classification Report for Baseline Model:")
print(classification_report(y_valid, baseline_predictions, zero_division=0))
# Out:
# Column names in the DataFrame: Index(['doc_id', 'titre', 'type', 'difficulte', 'cout', 'ingredients',
#        'recette'],
#       dtype='object')
# Classification Report for Baseline Model:
#                 precision    recall  f1-score   support
#
#        Dessert       0.00      0.00      0.00       726
#         Entrée       0.00      0.00      0.00       611
# Plat principal       0.46      1.00      0.63      1158
#
#       accuracy                           0.46      2495
#      macro avg       0.15      0.33      0.21      2495
#   weighted avg       0.22      0.46      0.29      2495

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# Naive Bayes Model
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)

# Logistic Regression Model
logreg_model = LogisticRegression(max_iter=1000)
logreg_model.fit(X_train, y_train)

# Random Forest Model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Support Vector Machine Model
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)


X_valid = vectorizer.transform(valid_df['titre'])  
y_valid = valid_df['type']  

# Evaluation des models
models = {
    'Baseline': baseline_model,
    'Naive Bayes': nb_model,
    'Logistic Regression': logreg_model,
    'Random Forest': rf_model,
    'Support Vector Machine': svm_model
}

for name, model in models.items():
    y_pred = model.predict(X_valid)
    print(f"Classification Report for {name} Model:")
    print(classification_report(y_valid, y_pred, zero_division=0))
# Out:
# Classification Report for Baseline Model:
#                 precision    recall  f1-score   support
#
#        Dessert       0.00      0.00      0.00       726
#         Entrée       0.00      0.00      0.00       611
# Plat principal       0.46      1.00      0.63      1158
#
#       accuracy                           0.46      2495
#      macro avg       0.15      0.33      0.21      2495
#   weighted avg       0.22      0.46      0.29      2495
#
# Classification Report for Naive Bayes Model:
#                 precision    recall  f1-score   support
#
#        Dessert       0.92      0.94      0.93       726
#         Entrée       0.72      0.56      0.63       611
# Plat principal       0.78      0.87      0.82      1158
#
#       accuracy                           0.81      2495
#      macro avg       0.81      0.79      0.79      2495
#   weighted avg       0.81      0.81      0.81      2495
#
# Classification Report for Logistic Regression Model:
# ...
